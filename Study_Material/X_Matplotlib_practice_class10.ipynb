# %% [markdown]
# # DATA VISUALIZATION USING PYTHON PROGRAMMING
#
# Matplotlib is a popular Python library for creating static, interactive, and animated visualizations.
# It provides a MATLAB-like interface and is used widely in AI, data analysis, and machine learning.

# %% [markdown]
# **Library:** A library is a collection of packages and modules that provide tools for performing specific types of tasks such as data analysis, visualization, or machine learning.

# %% [markdown]
# #Mathematical Plots **using Matplotlib library**

# %% [markdown]
# **Minimum requirement for a line plot**

# %%
import matplotlib.pyplot as plt   # Importing the matplotlib library for data visualization
x = [1, 2, 3, 4, 5]               # X-axis values
y = [2, 4, 6, 8, 10]              # Y-axis values
plt.plot(x, y)                    # Plot
plt.title("Basic Line Plot")      # Title
plt.xlabel("X-axis")              # X-axis label
plt.ylabel("Y-axis")              # Y-axis label
plt.show()

# %% [markdown]
# # **Line Graph**
#
# Write a Python program using Matplotlib to plot a **line graph** to visualize a simple relationship between X and Y
#    - X: `[1, 2, 3, 4, 5]`
#    - Y: `[2, 4, 6, 8, 10]`
#    - Add proper labels, title, legend, and grid.

# %%
# --------------------------------------------
# Program: Basic Line Plot using Matplotlib
# Objective: To visualize a simple linear relationship between X and Y
# --------------------------------------------

# Importing the matplotlib library for data visualization
import matplotlib.pyplot as plt

# Defining the data points for the X and Y axes
x = [1, 2, 3, 4, 5]          # X-axis values
y = [2, 4, 6, 8, 10]        # Corresponding Y-axis values (linear relation)

# Creating a line plot
# color     : defines the line color
# marker    : 'o' places circular markers on each data point
# linestyle : '--' makes the line dashed
plt.plot(x, y, color='blue', marker='o', linestyle='-.')

# Adding a descriptive title to the graph
plt.title("Basic Line Plot")

# Labeling the X and Y axes
plt.xlabel("X-axis")
plt.ylabel("Y-axis")

# Displaying a grid to make it easier to read the graph
plt.grid(True)

# Adding a legend to describe the plotted line
plt.legend(["Line 1 Legend"])

# Displaying the final plotted graph
plt.show()

# %% [markdown]
# # **Line Graph** -  Multiple line plot using different subplots
#
# Write a Python program using Matplotlib to plot multiple line plots using different subplots **line graph** to visualize and compare multiple variables together.
#    - X: `[1, 2, 3, 4, 5]`
#    - Y: `[1, 4, 9, 16, 25]`
#    - Z: `[25, 16, 9, 4, 1]`

# %%
# ----------------------------------------------------------
# Program: Subplot Example (Two Graphs in One Figure)
# Objective: To display two line plots side-by-side using subplots
# ----------------------------------------------------------

# Importing matplotlib for plotting
import matplotlib.pyplot as plt

# Defining X values (common for both graphs)
x = [1, 2, 3, 4, 5]

# Y values for the first graph (increasing pattern)
y = [1, 4, 9, 16, 25]

# Y values for the second graph (decreasing pattern)
z = [25, 16, 9, 4, 1]

# -----------------------------
# First Subplot (1 row, 2 columns, position 1)
# -----------------------------
plt.subplot(1, 2, 1)           # Layout: 1 row × 2 columns, this is subplot 1
plt.plot(x, y, color='blue', marker='o')
plt.title("Increasing")        # Title for first graph

# -----------------------------
# Second Subplot (same layout, position 2)
# -----------------------------
plt.subplot(1, 2, 2)           # Subplot position 2
plt.plot(x, z, color='red', marker='o')
plt.title("Decreasing")        # Title for second graph

# Adding a main title for the entire figure
plt.suptitle("Subplot Example")

# Displaying both subplots together
plt.show()

# %% [markdown]
# ## **BAR GRAPH:**
# Make a bar graph to display **marks scored by a student** in different subjects.
#    - subjects = `['Math', 'Science', 'English', 'AI']`
#    - marks = `[85, 90, 75, 95]`
#    - Use label, title and legend.

# %%
# ----------------------------------------------------------
# Program: Bar Graph of Student Marks
# Objective: To visualize marks scored by a student in different subjects
# ----------------------------------------------------------

# Importing matplotlib for creating the bar graph
import matplotlib.pyplot as plt

# Defining the categories (subjects) for the X-axis
subjects = ['Math', 'Science', 'English', 'AI']

# Marks scored by Student 1
marks = [85, 90, 75, 95]

# Creating the bar graph
# subjects → X-axis labels
# marks    → heights of bars
# color    → sets the bar color
plt.bar(subjects, marks, color='teal')

# Adding the graph title
plt.title("Student Marks in Different Subjects")

# Labeling X and Y axes
plt.xlabel("Subjects")
plt.ylabel("Marks")

# Adding a legend to describe the data
plt.legend(["Marks"])

# Displaying the bar graph
plt.show()

# %% [markdown]
# ## **Histogram**
# Write a Python program to draw a **histogram** to visualize the frequency distribution of numerical data:
#    - Marks: `[12, 15, 18, 19, 22, 24, 25, 29, 30, 32, 33, 35, 38, 40, 42, 45, 47, 50]`
#    - Use 5 bins.

# %%
# -------------------------------------------------------------
# Program: Histogram Example
# Objective: To visualize the frequency distribution of numerical data
# -------------------------------------------------------------

import matplotlib.pyplot as plt

# Sample numerical data
data = [12, 15, 18, 19, 22, 24, 25, 29, 30, 32, 33, 35, 38, 40, 42, 45, 47, 50]

# Creating the histogram
# data  → numerical values to group into bins
# bins  → number of intervals (groups)
# color → bar color
# edgecolor → outline color for bars
plt.hist(data, bins=5, color='skyblue', edgecolor='black')

# Adding title and axis labels
plt.title("Basic Histogram Example")
plt.xlabel("Value Range")
plt.ylabel("Frequency")

# Displaying the histogram
plt.show()

# %% [markdown]
# **Explanation**
#
# _plt.hist(data, bins=5, ...)_ → divides the data into 5 bins (groups) and shows how many values fall in each.

# %% [markdown]
# ## **Pie Chart**
# Draw a pie chart to show how many hours are spent on different **daily activities**:
# - Activities: `["Study", "Sleep", "Play", "Others"]`
# - Hours: `[8, 7, 5, 4]`
# - Use different colors, labels and pecentage value of each activity.

# %%
# -------------------------------------------------------------
# Program: Pie Chart - Daily Activity Distribution
# Objective: To show how many hours are spent on different daily activities
# -------------------------------------------------------------

import matplotlib.pyplot as plt

# Categories of daily activities
activities = ['Study', 'Sleep', 'Play', 'Others']

# Number of hours spent on each activity; numerical values that determine the size of each slice.
hours = [8, 7, 5, 4]

# Colors for each section of the pie chart
colors = ['gold', 'lightcoral', 'lightskyblue', 'yellowgreen']

# Creating the pie chart
# labels   → names of each activity
# colors   → assigns custom colors to each activity slice
# autopct  → display the percentage value on each slice
plt.pie(hours, labels=activities, colors=colors, autopct='%1.1f%%')

# Adding a title
plt.title("Daily Activity Distribution")

# Displaying the final pie chart
plt.show()

# %% [markdown]
# ## **Scatter Plot**
# Draw a Scatter Plot to show the relationship between **height and weight**:
# - height = `[150, 160, 165, 170, 175, 180]`
# - weight = `[50, 55, 60, 65, 72, 80]`
# - Use title and labels.

# %%
# -------------------------------------------------------------
# Program: Scatter Plot - Height vs Weight
# Objective: To visualize the relationship between height and weight
# -------------------------------------------------------------

# Importing matplotlib for plotting
import matplotlib.pyplot as plt

# List of heights (in centimeters)
height = [150, 160, 165, 170, 175, 180]

# Corresponding list of weights (in kilograms)
weight = [50, 55, 60, 65, 72, 80]

# Creating a scatter plot
# color = 'purple' sets the dot color
# s = 80 sets the marker size (size of each dot)
plt.scatter(height, weight, color='purple', s=50)

# Adding a title to the graph
plt.title("Height vs Weight")

# Labeling the X and Y axes
plt.xlabel("Height (cm)")
plt.ylabel("Weight (kg)")

# Adding a grid for clearer visibility
plt.grid(True)

# Displaying the scatter plot
plt.show()

# %% [markdown]
# # Matplotlib Practice Exercises- Do It Youself
#
# This set of exercises will help you practice basic plotting functions in the **Matplotlib** library — including Line Plot, Bar Graph, Histogram, and Pie Chart.

# %% [markdown]
# ##  1. Line Plot
# 1. Write a Python program using Matplotlib to plot a **line graph** showing marks of a student in 5 subjects.
#    - Subjects: `["Math", "Physics", "Chemistry", "English", "CS"]`
#    - Marks: `[85, 78, 92, 74, 88]`
#
# 2. Plot a line showing the **growth of a plant** over 6 weeks.
#    - Weeks: `[1, 2, 3, 4, 5, 6]`
#    - Height (cm): `[4, 7, 10, 15, 18, 22]`
#    Add proper labels, title, and grid.
#
# 3. Draw line plots using the subplot method to show the plots above **(Q1 & Q2)** together.

# %%
import matplotlib.pyplot as plt
subjects = ["Math", "Physics", "Chemistry", "English", "CS"]
marks = [85, 78, 92, 74, 88]
plt.plot(subjects, marks, color='blue', marker='o', linestyle='-.')
plt.title("Student Marks in Different Subjects")
plt.xlabel("Subjects")
plt.ylabel("Marks")
plt.grid(True)
plt.legend(["Line 1"])
plt.show()

# %%
import matplotlib.pyplot as plt
weeks = [1,2,3,4,5,6]
height = [4,7,10,15,18,22]
plt.plot(weeks, height, color='green', marker='o', linestyle='--')
plt.title("Growth of a Plant")
plt.xlabel("Weeks")
plt.ylabel("Height (cm)")
plt.grid(True)
#plt.legend(["Line 1"])
plt.show()

# %%
import matplotlib.pyplot as plt

subjects = ["Math", "Physics", "Chemistry", "English", "CS"]
marks = [85, 78, 92, 74, 88]
weeks = [1,2,3,4,5,6]
height = [4,7,10,15,18,22]

plt.subplot(2, 1, 1)
plt.plot(subjects, marks, color='blue', marker='o', linestyle='-.')
plt.title("Student Marks in Different Subjects")
plt.xlabel("Subjects")
plt.ylabel("Marks")
plt.show()

plt.subplot(2, 1, 2)
plt.plot(weeks, height, color='green', marker='o', linestyle='--')
plt.title("Growth of a Plant")
plt.xlabel("Weeks")
plt.ylabel("Height (cm)")
plt.show()

# %% [markdown]
# ## 2. Bar Graph
# 4. Create a bar chart showing the **number of students** in different clubs.
#    - Clubs: `["Science", "Drama", "Sports", "Music"]`
#    - Students: `[25, 18, 30, 22]`
#
# 5. Make a bar graph to display the **average temperature** of 5 cities.
#    - Cities: `["Delhi", "Mumbai", "Kolkata", "Chennai", "Bengaluru"]`
#    - Temperatures: `[35, 33, 30, 32, 28]`

# %% [markdown]
# ## 3. Histogram
# 6. Write a Python program to draw a **histogram** of student marks:
#    - Marks: `[45, 56, 67, 70, 80, 82, 90, 91, 60, 75, 68, 88, 77, 58, 84]`
#    - Use 5 bins.
#
# 7. Plot a histogram showing the **ages of employees** in a company.
#    - Ages: `[23, 25, 27, 28, 30, 32, 35, 36, 37, 38, 40, 42, 45, 47, 50]`
#
# 8. Generate a histogram of **random test scores** between 40 and 100 using `numpy.random.randint()`.

# %% [markdown]
# ## 4. Pie Chart
#
# 9. Create a pie chart for **types of devices used for online learning**:
#     - Devices: `["Mobile", "Laptop", "Tablet", "Desktop"]`
#     - Percentage: `[55, 30, 10, 5]`
#
# 10. Make a pie chart representing the **market share** of smartphone brands.
#     - Brands: `["Apple", "Samsung", "Xiaomi", "OnePlus", "Others"]`
#     - Share: `[25, 30, 20, 15, 10]`
